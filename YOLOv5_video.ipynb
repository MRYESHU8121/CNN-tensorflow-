# %% [markdown]
# <a href="https://colab.research.google.com/github/MRYESHU8121/CNN-tensorflow-/blob/main/YOLOv5_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15274, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 15274 (delta 11), reused 24 (delta 6), pack-reused 15236
# Receiving objects: 100% (15274/15274), 14.24 MiB | 14.69 MiB/s, done.
# Resolving deltas: 100% (10459/10459), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.9/78.2 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/object/videoplayback.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (1415/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 7 persons, 3 cars, 2 motorcycles, 1 bus, 10.2ms
# video 1/1 (1416/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 7 persons, 1 bicycle, 3 cars, 2 motorcycles, 1 bus, 8.4ms
# video 1/1 (1417/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 6 persons, 1 bicycle, 5 cars, 2 motorcycles, 1 bus, 1 backpack, 8.5ms
# video 1/1 (1418/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 7 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bus, 2 backpacks, 8.3ms
# video 1/1 (1419/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 9 persons, 2 bicycles, 3 cars, 1 motorcycle, 1 bus, 2 backpacks, 9.8ms
# video 1/1 (1420/6412) /content/drive/MyDrive/object/videoplayback.mp4: 384x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bus, 8.1ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Output File found in the path "/content/yolov5/runs/detect/exp2"
